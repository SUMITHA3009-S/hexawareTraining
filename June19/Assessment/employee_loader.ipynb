# %%
employee_data = [
    (101, "Arun", "IT", 50000),
    (102, "Priya", "HR", 45000),
    (103, "Karthik", "Finance", 60000),
    (104, "Meena", "Sales", 55000)
]

columns = ["emp_id", "name", "department", "salary"]

df = spark.createDataFrame(employee_data, columns)

display(df)

print("Employee Load Completed")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Arun</td><td>IT</td><td>50000</td></tr><tr><td>102</td><td>Priya</td><td>HR</td><td>45000</td></tr><tr><td>103</td><td>Karthik</td><td>Finance</td><td>60000</td></tr><tr><td>104</td><td>Meena</td><td>Sales</td><td>55000</td></tr></tbody></table></div>
# Employee Load Completed
