# %%
data = [
    (101,"Rahul",75000),
    (102,"Priya",85000),
    (103,"Amit",65000)
]

df = spark.createDataFrame(
    data,
    ["emp_id","name","salary"]
)

# %%
df.write.format("delta") \
.save("/tmp/employees_delta")

# %%
delta_df = spark.read.format("delta") \
.load("/tmp/employees_delta")
display(delta_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Rahul</td><td>75000</td></tr><tr><td>102</td><td>Priya</td><td>85000</td></tr><tr><td>103</td><td>Amit</td><td>65000</td></tr></tbody></table></div>

# %%
df.write.format("delta") \
.saveAsTable("employees")

# %%
# %sql
select * from employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Rahul</td><td>75000</td></tr><tr><td>102</td><td>Priya</td><td>85000</td></tr><tr><td>103</td><td>Amit</td><td>65000</td></tr></tbody></table></div>

# %%
# %sql
CREATE TABLE employees_delta
(
    emp_id INT,
    name STRING,
    salary INT
)
USING DELTA

# %%
# %sql
INSERT INTO employees_delta
VALUES
(101,'Rahul',75000),
(102,'Priya',85000)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %%
# %sql
select * from employees_delta
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Rahul</td><td>75000</td></tr><tr><td>102</td><td>Priya</td><td>85000</td></tr></tbody></table></div>

# %%
updates = [

(102,"Priya",90000),
(104,"Sneha",70000)

]

updates_df = spark.createDataFrame(
    updates,
    ["emp_id","name","salary"]
)

# %%
from delta.tables import DeltaTable

delta_table = DeltaTable.forPath(
    spark,
    "/tmp/employees_delta"
)
updates = [

(102,"Priya",90000),
(104,"Sneha",70000)

]

updates_df = spark.createDataFrame(
    updates,
    ["emp_id","name","salary"]
)

# %%
# %sql DESCRIBE HISTORY employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>0</td><td>2026-06-17T09:40:13Z</td><td>144642040528452</td><td>azuser7226_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>CREATE TABLE AS SELECT</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.parquet.compression.codec":"zstd","delta.enableDeletionVectors":"true"}, statsOnLoad -> true)</td><td>null</td><td>List(114506522194168)</td><td>0617-091944-l0zs91nf</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 1302)</td><td>null</td><td>Databricks-Runtime/17.3.x-photon-scala2.13</td></tr></tbody></table></div>

# %%
df = spark.read.format("delta")\
.option("versionAsOf",0)\
.load("/tmp/employees_delta")
 
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>101</td><td>Rahul</td><td>75000</td></tr><tr><td>102</td><td>Priya</td><td>85000</td></tr><tr><td>103</td><td>Amit</td><td>65000</td></tr></tbody></table></div>

# %%
# %sql OPTIMIZE employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>abfss://unity-catalog-storage@dbstorageimuuwwlwde2xc.dfs.core.windows.net/7405609256999242/__unitystorage/catalogs/397e9ec3-bb37-4774-aa90-697bbb227f1a/tables/de88e1ff-b757-4f07-8d98-8c84e87d654f</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, null, null, 0, 0, 1, 1, true, 0, 0, 1781690557156, 1781690557898, 8, 0, null, List(0, 0), null, 3, 3, 0, 0, null)</td></tr></tbody></table></div>

# %%
# %sql OPTIMIZE employees
ZORDER BY(name)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>abfss://unity-catalog-storage@dbstorageimuuwwlwde2xc.dfs.core.windows.net/7405609256999242/__unitystorage/catalogs/397e9ec3-bb37-4774-aa90-697bbb227f1a/tables/de88e1ff-b757-4f07-8d98-8c84e87d654f</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, List(minCubeSize(107374182400), List(0, 0), List(1, 1302), 0, List(0, 0), 0, null), null, 0, 0, 1, 1, false, 0, 0, 1781690908477, 1781690909215, 8, 0, null, List(0, 0), null, 3, 3, 0, 0, null)</td></tr></tbody></table></div>

# %%
# %sql VACUUM employees
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>abfss://unity-catalog-storage@dbstorageimuuwwlwde2xc.dfs.core.windows.net/7405609256999242/__unitystorage/catalogs/397e9ec3-bb37-4774-aa90-697bbb227f1a/tables/de88e1ff-b757-4f07-8d98-8c84e87d654f</td></tr></tbody></table></div>
